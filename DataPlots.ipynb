# %%
import numpy as np
from BaseEnv import BaseClass

# %%
tickers = ['spy','aapl']
Base = BaseClass(tickers = tickers)

Base.visualization_bVSc_3D(tickers = tickers)
Base.visualization_bVSc(tickers = tickers)
Base.visualization_ts_bc(tickers = tickers)

# %%
tickers = ['spy','aapl','a']
Base = BaseClass(tickers = tickers)

ticker = 'aapl'

#Base.y_valid[ticker]

Base.y_train[ticker].shape[1] if len(Base.y_train[ticker].shape) > 1 else 1


Base.X_train[ticker][..., np.newaxis][0]

(Base.X_train[ticker].shape[1], 1)

# feature_steps = 10
# target_steps = 2
# n_obs = len(Base.ts) - feature_steps - target_steps + 1
# idx = 0#in range(n_obs)
# Base.ts[ticker][idx + feature_steps:idx + feature_steps + target_steps][-1,:]
# Out:
# (10, 1)
