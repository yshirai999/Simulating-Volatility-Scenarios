# %%
import numpy as np
from BaseEnv import BaseClass

#C:\Users\yoshi\OneDrive\Desktop\Research\ConvexLevyProcesses\Simulating-Volatility-Scenarios\Data1\BGP1.mat

# %%
tickers = ['aapl','spy','gs','amzn']
Base = BaseClass(tickers = tickers)

Base.visualization_bVSc_3D(tickers = tickers)
Base.visualization_bVSc(tickers = tickers)
Base.visualization_ts_bc(tickers = tickers)

# %%
from matplotlib import pyplot as plt
tickers = 'spy'

bp = Base.df[tickers]["bp"].values
cp = Base.df[tickers]["cp"].values
bn = Base.df[tickers]["bn"].values
cn = Base.df[tickers]["cn"].values

fig = plt.scatter(bp, bn)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Dbp = Base.X_train[tickers][:,:,0]
Dbn = Base.X_train[tickers][:,:,1]

fig = plt.scatter(Dbp, Dbn)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
